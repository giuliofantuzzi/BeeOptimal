# %%
from beeoptimal import contourplot_bees
from beeoptimal.benchmarks import Weierstrass2d
from beeoptimal import Bee
import numpy as np

# %%
bee = Bee(position=np.array([0,0]),function=Weierstrass2d,bounds=np.array([[-10,10],[-10,10]]))

# %%
contourplot_bees(
    function= Weierstrass2d,
    title = "Weierstrass 2D",
    bee_colony=[bee]
)
